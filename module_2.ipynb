# %%
import os, json, numpy as np, pandas as pd
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, f1_score, accuracy_score

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import joblib

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
## Load data & normalize column names

CSV_PATH = "Crop_recommendation.csv"   # adjust if needed
df = pd.read_csv(CSV_PATH)
df.columns = df.columns.str.strip()

# 1) Drop any Unnamed or fully-empty columns
df = df.loc[:, ~df.columns.str.match(r"^Unnamed", case=False)]
df = df.dropna(axis=1, how="all")

# Ensure standard names
COL_MAP = {'Nitrogen':'N','phosphorus':'P','potassium':'K'}
df = df.rename(columns={k:v for k,v in COL_MAP.items() if k in df.columns})

required = {'N','P','K','temperature','humidity','ph','rainfall','label'}
missing = required - set(df.columns)
assert not missing, f"Missing columns: {missing}"

df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
## Preprocessing: target encoding, split, scaling
# Target encode
y_cats = df['label'].astype('category')
y = y_cats.cat.codes.values
classes = list(y_cats.cat.categories)

# Features
X = df[['N','P','K','temperature','humidity','ph','rainfall']].astype('float32').values

# Stratified 70/15/15
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, stratify=y, random_state=RANDOM_SEED
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1765, stratify=y_train, random_state=RANDOM_SEED
)  # 0.1765 ≈ 15% of (train+val)

# Scale (trees don’t need it, but keeps swap-to-MLP easy)
scaler = StandardScaler().fit(X_train)
Xs_train = scaler.transform(X_train)
Xs_val   = scaler.transform(X_val)
Xs_test  = scaler.transform(X_test)

len(classes), classes[:5]
# Out:
# (22, ['apple', 'banana', 'blackgram', 'chickpea', 'coconut'])

# %%
## Helper: train/eval wrapper

def evaluate_model(model, X_tr, y_tr, X_va, y_va, X_te, y_te, name="model", **fit_kwargs):
    """
    Trains model with optional fit kwargs (e.g., eval_set for XGBoost >=3.x),
    prints metrics, and returns results dict.
    """
    model.fit(X_tr, y_tr, **fit_kwargs)

    # Validation metrics
    va_pred = model.predict(X_va)
    va_f1   = f1_score(y_va, va_pred, average="macro")
    va_acc  = accuracy_score(y_va, va_pred)

    # Test metrics
    te_pred = model.predict(X_te)
    te_f1   = f1_score(y_te, te_pred, average="macro")
    te_acc  = accuracy_score(y_te, te_pred)

    print(f"\n=== {name} ===")
    print("Validation -> macro-F1:", round(va_f1,4), "  acc:", round(va_acc,4))
    print("Test       -> macro-F1:", round(te_f1,4), "  acc:", round(te_acc,4))
    print("\nClassification report (test):")
    print(classification_report(y_te, te_pred, target_names=classes, digits=3))

    return {"name":name, "model":model,
            "val_f1":va_f1, "val_acc":va_acc,
            "test_f1":te_f1, "test_acc":te_acc}

# %%
rf = RandomForestClassifier(
    n_estimators=400,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features="sqrt",
    class_weight="balanced_subsample",
    random_state=RANDOM_SEED,
    n_jobs=-1
)

res_rf = evaluate_model(
    rf, Xs_train, y_train, Xs_val, y_val, Xs_test, y_test, name="RandomForest"
)
# Out:
# === RandomForest ===
# Validation -> macro-F1: 1.0   acc: 1.0
# Test       -> macro-F1: 0.9939   acc: 0.9939
#
# Classification report (test):
#               precision    recall  f1-score   support
#
#        apple      1.000     1.000     1.000        15
#       banana      1.000     1.000     1.000        15
#    blackgram      1.000     0.933     0.966        15
#     chickpea      1.000     1.000     1.000        15
#      coconut      1.000     1.000     1.000        15
#       coffee      1.000     1.000     1.000        15
#       cotton      1.000     1.000     1.000        15
#       grapes      1.000     1.000     1.000        15
#         jute      0.938     1.000     0.968        15
#  kidneybeans      1.000     1.000     1.000        15
#       lentil      1.000     1.000     1.000        15
#        maize      0.938     1.000     0.968        15
#        mango      1.000     1.000     1.000        15
#    mothbeans      1.000     1.000     1.000        15
#     mungbean      1.000     1.000     1.000        15
#    muskmelon      1.000     1.000     1.000        15
#       orange      1.000     1.000     1.000        15
#       papaya      1.000     1.000     1.000        15
#   pigeonpeas      1.000     1.000     1.000        15
#  pomegranate      1.000     1.000     1.000        15
#         rice      1.000     0.933     0.966        15
#   watermelon      1.000     1.000     1.000        15
#
#     accuracy                          0.994       330
#    macro avg      0.994     0.994     0.994       330
# weighted avg      0.994     0.994     0.994       330

# %%
xgb_clf = xgb.XGBClassifier(
    objective="multi:softprob",
    eval_metric="mlogloss",
    early_stopping_rounds=30,   # set on the estimator (>=3.x)
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.9,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    tree_method="hist",
    random_state=RANDOM_SEED,
    n_jobs=-1,
    num_class=len(classes)
)

res_xgb = evaluate_model(
    xgb_clf, Xs_train, y_train, Xs_val, y_val, Xs_test, y_test,
    name="XGBoost (>=3.x)",
    eval_set=[(Xs_val, y_val)],
    verbose=False
)
# Out:
# === XGBoost (>=3.x) ===
# Validation -> macro-F1: 0.994   acc: 0.994
# Test       -> macro-F1: 0.9909   acc: 0.9909
#
# Classification report (test):
#               precision    recall  f1-score   support
#
#        apple      1.000     1.000     1.000        15
#       banana      1.000     1.000     1.000        15
#    blackgram      0.933     0.933     0.933        15
#     chickpea      1.000     1.000     1.000        15
#      coconut      1.000     1.000     1.000        15
#       coffee      1.000     1.000     1.000        15
#       cotton      1.000     1.000     1.000        15
#       grapes      1.000     1.000     1.000        15
#         jute      1.000     1.000     1.000        15
#  kidneybeans      1.000     1.000     1.000        15
#       lentil      1.000     0.933     0.966        15
#        maize      1.000     1.000     1.000        15
#        mango      1.000     1.000     1.000        15
#    mothbeans      0.938     1.000     0.968        15
#     mungbean      0.938     1.000     0.968        15
#    muskmelon      1.000     1.000     1.000        15
#       orange      1.000     1.000     1.000        15
#       papaya      1.000     1.000     1.000        15
#   pigeonpeas      1.000     0.933     0.966        15
#  pomegranate      1.000     1.000     1.000        15
#         rice      1.000     1.000     1.000        15
#   watermelon      1.000     1.000     1.000        15
#
#     accuracy                          0.991       330
#    macro avg      0.991     0.991     0.991       330
# weighted avg      0.991     0.991     0.991       330

# %%
results = [res_rf, res_xgb]
best = max(results, key=lambda r: r["val_f1"])
print("\nBest model by validation F1:", best["name"], "->", round(best["val_f1"],4))

Path("artifacts").mkdir(exist_ok=True)
joblib.dump(best["model"], "artifacts/model_best.joblib")
joblib.dump(scaler,       "artifacts/scaler.joblib")
joblib.dump(classes,      "artifacts/classes.joblib")

best
# Out:
# Best model by validation F1: RandomForest -> 1.0
# {'name': 'RandomForest',
#  'model': RandomForestClassifier(class_weight='balanced_subsample', n_estimators=400,
#                         n_jobs=-1, random_state=42),
#  'val_f1': 1.0,
#  'val_acc': 1.0,
#  'test_f1': 0.9939326524421074,
#  'test_acc': 0.9939393939393939}

# %%
def load_artifacts():
    model   = joblib.load("artifacts/model_best.joblib")
    scaler  = joblib.load("artifacts/scaler.joblib")
    classes = joblib.load("artifacts/classes.joblib")
    return model, scaler, classes

def predict_one(sample_dict):
    # keys: N,P,K,temperature,humidity,ph,rainfall
    order = ['N','P','K','temperature','humidity','ph','rainfall']
    x = np.array([[sample_dict[k] for k in order]], dtype=np.float32)
    model, sc, cls = load_artifacts()
    x = sc.transform(x)
    proba = model.predict_proba(x)[0]
    top = int(np.argmax(proba))
    return {"crop": cls[top], "confidence": float(proba[top])}

# Example
predict_one({"N":90,"P":42,"K":43,"temperature":21.5,"humidity":80,"ph":6.5,"rainfall":200})
# Out:
# {'crop': 'rice', 'confidence': 0.7875}

# %%
pip install streamlit streamlit-webrtc faster-whisper edge-tts av joblib scikit-learn
# Out:
# Collecting streamlitNote: you may need to restart the kernel to use updated packages.
#
#   Using cached streamlit-1.50.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting streamlit-webrtc
#   Using cached streamlit_webrtc-0.63.11-py3-none-any.whl.metadata (18 kB)
# Collecting faster-whisper
#   Using cached faster_whisper-1.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting edge-tts
#   Using cached edge_tts-7.2.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting av
#   Using cached av-16.0.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: joblib in c:\stevens\ats\venv\lib\site-packages (1.5.2)
# Requirement already satisfied: scikit-learn in c:\stevens\ats\venv\lib\site-packages (1.7.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (5.2.0)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<26,>=20 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (2.2.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (10.2.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (15.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (4.10.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (4.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (3.1.42)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\navne\appdata\roaming\python\python312\site-packages (from streamlit) (6.4)
# Collecting aioice>=0.10.1 (from streamlit-webrtc)
#   Using cached aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting aiortc>=1.11.0 (from streamlit-webrtc)
#   Using cached aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Using cached ctranslate2-4.6.0-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting huggingface-hub>=0.13 (from faster-whisper)
#   Using cached huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting tokenizers<1,>=0.13 (from faster-whisper)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Using cached onnxruntime-1.23.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in c:\users\navne\appdata\roaming\python\python312\site-packages (from faster-whisper) (4.66.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from edge-tts) (3.9.3)
# Requirement already satisfied: certifi>=2023.11.17 in c:\users\navne\appdata\roaming\python\python312\site-packages (from edge-tts) (2024.2.2)
# Requirement already satisfied: tabulate<1.0.0,>=0.4.4 in c:\stevens\ats\venv\lib\site-packages (from edge-tts) (0.9.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\stevens\ats\venv\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\stevens\ats\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\navne\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\navne\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.9.4)
# Collecting dnspython>=2.0.0 (from aioice>=0.10.1->streamlit-webrtc)
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\stevens\ats\venv\lib\site-packages (from aioice>=0.10.1->streamlit-webrtc) (0.2.0)
# Collecting cryptography>=44.0.0 (from aiortc>=1.11.0->streamlit-webrtc)
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting google-crc32c>=1.1 (from aiortc>=1.11.0->streamlit-webrtc)
#   Using cached google_crc32c-1.7.1-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting pyee>=13.0.0 (from aiortc>=1.11.0->streamlit-webrtc)
#   Using cached pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.11.0->streamlit-webrtc)
#   Using cached pylibsrtp-1.0.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.11.0->streamlit-webrtc)
#   Using cached pyopenssl-25.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jinja2 in c:\users\navne\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.21.1)
# Requirement already satisfied: toolz in c:\users\navne\appdata\roaming\python\python312\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\navne\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: setuptools in c:\stevens\ats\venv\lib\site-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.8.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in c:\users\navne\appdata\roaming\python\python312\site-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Collecting filelock (from huggingface-hub>=0.13->faster-whisper)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.13->faster-whisper)
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\stevens\ats\venv\lib\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.9.23)
# Requirement already satisfied: sympy in c:\stevens\ats\venv\lib\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\navne\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\navne\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\navne\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\navne\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from requests<3,>=2.27->streamlit) (2.2.1)
# Collecting cffi>=2.0.0 (from cryptography>=44.0.0->aiortc>=1.11.0->streamlit-webrtc)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\navne\appdata\roaming\python\python312\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\navne\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\navne\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\navne\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\navne\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\stevens\ats\venv\lib\site-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.11.0->streamlit-webrtc)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Using cached streamlit-1.50.0-py3-none-any.whl (10.1 MB)
# Using cached streamlit_webrtc-0.63.11-py3-none-any.whl (220 kB)
# Using cached faster_whisper-1.2.0-py3-none-any.whl (1.1 MB)
# Using cached edge_tts-7.2.3-py3-none-any.whl (30 kB)
# Using cached av-16.0.1-cp312-cp312-win_amd64.whl (32.3 MB)
# Using cached aioice-0.10.1-py3-none-any.whl (24 kB)
# Using cached aiortc-1.14.0-py3-none-any.whl (93 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached ctranslate2-4.6.0-cp312-cp312-win_amd64.whl (19.5 MB)
# Using cached huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
# Using cached onnxruntime-1.23.1-cp312-cp312-win_amd64.whl (13.5 MB)
# Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Using cached fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Using cached google_crc32c-1.7.1-cp312-cp312-win_amd64.whl (33 kB)
# Using cached pyee-13.0.0-py3-none-any.whl (15 kB)
# Using cached pylibsrtp-1.0.0-cp310-abi3-win_amd64.whl (1.6 MB)
# Using cached pyopenssl-25.3.0-py3-none-any.whl (57 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: pyreadline3, pyee, pycparser, protobuf, google-crc32c, fsspec, filelock, dnspython, ctranslate2, blinker, av, humanfriendly, huggingface-hub, cffi, aioice, tokenizers, pylibsrtp, edge-tts, cryptography, coloredlogs, pyopenssl, onnxruntime, streamlit, faster-whisper, aiortc, streamlit-webrtc
# Successfully installed aioice-0.10.1 aiortc-1.14.0 av-16.0.1 blinker-1.9.0 cffi-2.0.0 coloredlogs-15.0.1 cryptography-46.0.3 ctranslate2-4.6.0 dnspython-2.8.0 edge-tts-7.2.3 faster-whisper-1.2.0 filelock-3.20.0 fsspec-2025.9.0 google-crc32c-1.7.1 huggingface-hub-0.35.3 humanfriendly-10.0 onnxruntime-1.23.1 protobuf-6.33.0 pycparser-2.23 pyee-13.0.0 pylibsrtp-1.0.0 pyopenssl-25.3.0 pyreadline3-3.5.4 streamlit-1.50.0 streamlit-webrtc-0.63.11 tokenizers-0.22.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googleapis-common-protos 1.62.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 6.33.0 which is incompatible.
# google-ai-generativelanguage 0.4.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 6.33.0 which is incompatible.
# google-api-core 2.17.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 6.33.0 which is incompatible.
# proto-plus 1.23.0 requires protobuf<5.0.0dev,>=3.19.0, but you have protobuf 6.33.0 which is incompatible.
